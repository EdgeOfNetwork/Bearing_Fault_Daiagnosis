# %%
# Data science libraries
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Others
from IPython.core.debugger import set_trace
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11892/2121605834.py in <module>
#       6 from sklearn.model_selection import train_test_split
#       7
# ----> 8 import tensorflow as tf
#       9 from tensorflow import keras
#      10 from tensorflow.keras import layers
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install tensorflow

# %%
from sklearn.preprocessing import StandardScaler

def scaling(data):
  scaler = StandardScaler()
  scaler.fit(data)
  return scaler.transform(data)

# %%
path = "/content/drive/MyDrive/Bearing/bearing_test_1/"

df = pd.read_csv(path + "bearing_concat.csv")

features = df.columns[:400]
target = 'target'
random_seed = 42

## Split the data into train and validation set
x_train, x_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.20, random_state=random_seed, shuffle=True)

x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

x_train = scaling(x_train)
x_test = scaling(x_test)

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x) #여기서 뻑이났는데
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

# %%
model = build_model(input_shape,head_size=256, num_heads=4,ff_dim=4,num_transformer_blocks=4,mlp_units=[128],mlp_dropout=0.4,dropout=0.25,)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=["sparse_categorical_accuracy"],)

model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

hist = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=128,callbacks=callbacks)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 400, 1)]     0           []
#
#  layer_normalization_8 (LayerNo  (None, 400, 1)      2           ['input_2[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 400, 1)      7169        ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 400, 1)       0           ['multi_head_attention_4[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 400, 1)      0           ['dropout_9[0][0]',
#  mbda)                                                            'input_2[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 400, 1)      2           ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  conv1d_8 (Conv1D)              (None, 400, 4)       8           ['layer_normalization_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 400, 4)       0           ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 400, 1)       5           ['dropout_10[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 400, 1)      0           ['conv1d_9[0][0]',
#  mbda)                                                            'tf.__operators__.add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 400, 1)      7169        ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 400, 1)       0           ['multi_head_attention_5[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 400, 1)      0           ['dropout_11[0][0]',
#  ambda)                                                           'tf.__operators__.add_9[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_10[0][0]']
#  ormalization)
#
#  conv1d_10 (Conv1D)             (None, 400, 4)       8           ['layer_normalization_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 400, 4)       0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 400, 1)       5           ['dropout_12[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 400, 1)      0           ['conv1d_11[0][0]',
#  ambda)                                                           'tf.__operators__.add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_11[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 400, 1)      7169        ['layer_normalization_12[0][0]',
#  eadAttention)                                                    'layer_normalization_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 400, 1)       0           ['multi_head_attention_6[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 400, 1)      0           ['dropout_13[0][0]',
#  ambda)                                                           'tf.__operators__.add_11[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_12[0][0]']
#  ormalization)
#
#  conv1d_12 (Conv1D)             (None, 400, 4)       8           ['layer_normalization_13[0][0]']
#
#  dropout_14 (Dropout)           (None, 400, 4)       0           ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 400, 1)       5           ['dropout_14[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 400, 1)      0           ['conv1d_13[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_13[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 400, 1)      7169        ['layer_normalization_14[0][0]',
#  eadAttention)                                                    'layer_normalization_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 400, 1)       0           ['multi_head_attention_7[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 400, 1)      0           ['dropout_15[0][0]',
#  ambda)                                                           'tf.__operators__.add_13[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 400, 1)      2           ['tf.__operators__.add_14[0][0]']
#  ormalization)
#
#  conv1d_14 (Conv1D)             (None, 400, 4)       8           ['layer_normalization_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 400, 4)       0           ['conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 400, 1)       5           ['dropout_16[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 400, 1)      0           ['conv1d_15[0][0]',
#  ambda)                                                           'tf.__operators__.add_14[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 400)         0           ['tf.__operators__.add_15[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 128)          51328       ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dropout_17 (Dropout)           (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 10)           1290        ['dropout_17[0][0]']
#
# ==================================================================================================
# Total params: 81,362
# Trainable params: 81,362
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 60/60 [==============================] - 30s 454ms/step - loss: 0.3533 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.3946 - val_sparse_categorical_accuracy: 0.8854
# Epoch 2/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3502 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8880
# Epoch 3/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3525 - sparse_categorical_accuracy: 0.8974 - val_loss: 0.3928 - val_sparse_categorical_accuracy: 0.8870
# Epoch 4/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3538 - sparse_categorical_accuracy: 0.8915 - val_loss: 0.3896 - val_sparse_categorical_accuracy: 0.8880
# Epoch 5/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3422 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.3872 - val_sparse_categorical_accuracy: 0.8849
# Epoch 6/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.3884 - val_sparse_categorical_accuracy: 0.8844
# Epoch 7/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3408 - sparse_categorical_accuracy: 0.8999 - val_loss: 0.3856 - val_sparse_categorical_accuracy: 0.8849
# Epoch 8/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3424 - sparse_categorical_accuracy: 0.8988 - val_loss: 0.3825 - val_sparse_categorical_accuracy: 0.8896
# Epoch 9/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3378 - sparse_categorical_accuracy: 0.9001 - val_loss: 0.3815 - val_sparse_categorical_accuracy: 0.8865
# Epoch 10/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3365 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.3845 - val_sparse_categorical_accuracy: 0.8859
# Epoch 11/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3414 - sparse_categorical_accuracy: 0.8960 - val_loss: 0.3821 - val_sparse_categorical_accuracy: 0.8859
# Epoch 12/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3351 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.3824 - val_sparse_categorical_accuracy: 0.8891
# Epoch 13/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3346 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.3789 - val_sparse_categorical_accuracy: 0.8865
# Epoch 14/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3356 - sparse_categorical_accuracy: 0.8999 - val_loss: 0.3795 - val_sparse_categorical_accuracy: 0.8865
# Epoch 15/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3358 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.3749 - val_sparse_categorical_accuracy: 0.8901
# Epoch 16/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3327 - sparse_categorical_accuracy: 0.8980 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8906
# Epoch 17/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3289 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3739 - val_sparse_categorical_accuracy: 0.8917
# Epoch 18/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3220 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8885
# Epoch 19/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3328 - sparse_categorical_accuracy: 0.8986 - val_loss: 0.3735 - val_sparse_categorical_accuracy: 0.8891
# Epoch 20/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3244 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3706 - val_sparse_categorical_accuracy: 0.8891
# Epoch 21/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3210 - sparse_categorical_accuracy: 0.9044 - val_loss: 0.3675 - val_sparse_categorical_accuracy: 0.8896
# Epoch 22/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3201 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.3684 - val_sparse_categorical_accuracy: 0.8901
# Epoch 23/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3147 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.3647 - val_sparse_categorical_accuracy: 0.8896
# Epoch 24/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3138 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3652 - val_sparse_categorical_accuracy: 0.8906
# Epoch 25/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3134 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.3684 - val_sparse_categorical_accuracy: 0.8896
# Epoch 26/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3159 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.8927
# Epoch 27/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3164 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.3627 - val_sparse_categorical_accuracy: 0.8906
# Epoch 28/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3159 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8911
# Epoch 29/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3086 - sparse_categorical_accuracy: 0.9072 - val_loss: 0.3601 - val_sparse_categorical_accuracy: 0.8917
# Epoch 30/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3098 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.3603 - val_sparse_categorical_accuracy: 0.8906
# Epoch 31/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3082 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3551 - val_sparse_categorical_accuracy: 0.8948
# Epoch 32/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3106 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.8938
# Epoch 33/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.3588 - val_sparse_categorical_accuracy: 0.8922
# Epoch 34/200
# 60/60 [==============================] - 27s 453ms/step - loss: 0.3112 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3548 - val_sparse_categorical_accuracy: 0.8932
# Epoch 35/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3001 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.3550 - val_sparse_categorical_accuracy: 0.8938
# Epoch 36/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3054 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.3527 - val_sparse_categorical_accuracy: 0.8953
# Epoch 37/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.3542 - val_sparse_categorical_accuracy: 0.8922
# Epoch 38/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9056 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.8927
# Epoch 39/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2973 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3510 - val_sparse_categorical_accuracy: 0.8932
# Epoch 40/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2981 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.8938
# Epoch 41/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3048 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.3540 - val_sparse_categorical_accuracy: 0.8943
# Epoch 42/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2902 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 0.8969
# Epoch 43/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.3103 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8917
# Epoch 44/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2946 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.3464 - val_sparse_categorical_accuracy: 0.8958
# Epoch 45/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2946 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.3452 - val_sparse_categorical_accuracy: 0.8958
# Epoch 46/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2881 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.3475 - val_sparse_categorical_accuracy: 0.8948
# Epoch 47/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2957 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8953
# Epoch 48/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2918 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.3422 - val_sparse_categorical_accuracy: 0.8953
# Epoch 49/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2929 - sparse_categorical_accuracy: 0.9134 - val_loss: 0.3466 - val_sparse_categorical_accuracy: 0.8953
# Epoch 50/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.8964
# Epoch 51/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2876 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.3419 - val_sparse_categorical_accuracy: 0.8969
# Epoch 52/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2892 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.8969
# Epoch 53/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2876 - sparse_categorical_accuracy: 0.9171 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8974
# Epoch 54/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.3402 - val_sparse_categorical_accuracy: 0.8979
# Epoch 55/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2870 - sparse_categorical_accuracy: 0.9154 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.8984
# Epoch 56/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2809 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3384 - val_sparse_categorical_accuracy: 0.8979
# Epoch 57/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.8974
# Epoch 58/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2812 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.9000
# Epoch 59/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2774 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8979
# Epoch 60/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.3368 - val_sparse_categorical_accuracy: 0.8979
# Epoch 61/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2791 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.3329 - val_sparse_categorical_accuracy: 0.8990
# Epoch 62/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.3324 - val_sparse_categorical_accuracy: 0.8995
# Epoch 63/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3359 - val_sparse_categorical_accuracy: 0.8974
# Epoch 64/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2796 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.9010
# Epoch 65/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2676 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.3336 - val_sparse_categorical_accuracy: 0.8969
# Epoch 66/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.3328 - val_sparse_categorical_accuracy: 0.8995
# Epoch 67/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2711 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.3286 - val_sparse_categorical_accuracy: 0.9010
# Epoch 68/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2657 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.3293 - val_sparse_categorical_accuracy: 0.9016
# Epoch 69/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.9016
# Epoch 70/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2703 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.3276 - val_sparse_categorical_accuracy: 0.8995
# Epoch 71/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2763 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.3261 - val_sparse_categorical_accuracy: 0.9000
# Epoch 72/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.3270 - val_sparse_categorical_accuracy: 0.9000
# Epoch 73/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2698 - sparse_categorical_accuracy: 0.9171 - val_loss: 0.3259 - val_sparse_categorical_accuracy: 0.9005
# Epoch 74/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.9005
# Epoch 75/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2627 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.3244 - val_sparse_categorical_accuracy: 0.9000
# Epoch 76/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2675 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.3225 - val_sparse_categorical_accuracy: 0.9010
# Epoch 77/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2631 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.9005
# Epoch 78/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.3217 - val_sparse_categorical_accuracy: 0.8974
# Epoch 79/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2592 - sparse_categorical_accuracy: 0.9228 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.9021
# Epoch 80/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2542 - sparse_categorical_accuracy: 0.9283 - val_loss: 0.3192 - val_sparse_categorical_accuracy: 0.9005
# Epoch 81/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2595 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.3211 - val_sparse_categorical_accuracy: 0.9010
# Epoch 82/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2604 - sparse_categorical_accuracy: 0.9234 - val_loss: 0.3187 - val_sparse_categorical_accuracy: 0.9026
# Epoch 83/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2548 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.3214 - val_sparse_categorical_accuracy: 0.9010
# Epoch 84/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2542 - sparse_categorical_accuracy: 0.9257 - val_loss: 0.3168 - val_sparse_categorical_accuracy: 0.9021
# Epoch 85/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2544 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3197 - val_sparse_categorical_accuracy: 0.9021
# Epoch 86/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2545 - sparse_categorical_accuracy: 0.9275 - val_loss: 0.3171 - val_sparse_categorical_accuracy: 0.9026
# Epoch 87/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2519 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.9047
# Epoch 88/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2581 - sparse_categorical_accuracy: 0.9232 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.9016
# Epoch 89/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2542 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.3163 - val_sparse_categorical_accuracy: 0.9068
# Epoch 90/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2548 - sparse_categorical_accuracy: 0.9238 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.9021
# Epoch 91/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2495 - sparse_categorical_accuracy: 0.9290 - val_loss: 0.3154 - val_sparse_categorical_accuracy: 0.9036
# Epoch 92/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2482 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.3148 - val_sparse_categorical_accuracy: 0.9021
# Epoch 93/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2460 - sparse_categorical_accuracy: 0.9311 - val_loss: 0.3127 - val_sparse_categorical_accuracy: 0.9016
# Epoch 94/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2421 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.9036
# Epoch 95/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2462 - sparse_categorical_accuracy: 0.9272 - val_loss: 0.3120 - val_sparse_categorical_accuracy: 0.9021
# Epoch 96/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2481 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.3120 - val_sparse_categorical_accuracy: 0.9052
# Epoch 97/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9316 - val_loss: 0.3143 - val_sparse_categorical_accuracy: 0.9036
# Epoch 98/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2404 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.3069 - val_sparse_categorical_accuracy: 0.9057
# Epoch 99/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2337 - sparse_categorical_accuracy: 0.9329 - val_loss: 0.3079 - val_sparse_categorical_accuracy: 0.9068
# Epoch 100/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2490 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.3087 - val_sparse_categorical_accuracy: 0.9068
# Epoch 101/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2521 - sparse_categorical_accuracy: 0.9238 - val_loss: 0.3080 - val_sparse_categorical_accuracy: 0.9057
# Epoch 102/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2332 - sparse_categorical_accuracy: 0.9348 - val_loss: 0.3042 - val_sparse_categorical_accuracy: 0.9068
# Epoch 103/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2372 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.3050 - val_sparse_categorical_accuracy: 0.9073
# Epoch 104/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2422 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.3031 - val_sparse_categorical_accuracy: 0.9089
# Epoch 105/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2308 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.3073 - val_sparse_categorical_accuracy: 0.9083
# Epoch 106/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2366 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.3033 - val_sparse_categorical_accuracy: 0.9099
# Epoch 107/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2450 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.3040 - val_sparse_categorical_accuracy: 0.9083
# Epoch 108/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2363 - sparse_categorical_accuracy: 0.9344 - val_loss: 0.3038 - val_sparse_categorical_accuracy: 0.9073
# Epoch 109/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2454 - sparse_categorical_accuracy: 0.9251 - val_loss: 0.3061 - val_sparse_categorical_accuracy: 0.9094
# Epoch 110/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2418 - sparse_categorical_accuracy: 0.9268 - val_loss: 0.3049 - val_sparse_categorical_accuracy: 0.9078
# Epoch 111/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2317 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.3002 - val_sparse_categorical_accuracy: 0.9099
# Epoch 112/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2367 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.3017 - val_sparse_categorical_accuracy: 0.9062
# Epoch 113/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2326 - sparse_categorical_accuracy: 0.9311 - val_loss: 0.2998 - val_sparse_categorical_accuracy: 0.9083
# Epoch 114/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2300 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.2991 - val_sparse_categorical_accuracy: 0.9094
# Epoch 115/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2295 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.2956 - val_sparse_categorical_accuracy: 0.9099
# Epoch 116/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2242 - sparse_categorical_accuracy: 0.9350 - val_loss: 0.2943 - val_sparse_categorical_accuracy: 0.9094
# Epoch 117/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9314 - val_loss: 0.2981 - val_sparse_categorical_accuracy: 0.9073
# Epoch 118/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2374 - sparse_categorical_accuracy: 0.9290 - val_loss: 0.2992 - val_sparse_categorical_accuracy: 0.9083
# Epoch 119/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2312 - sparse_categorical_accuracy: 0.9309 - val_loss: 0.2944 - val_sparse_categorical_accuracy: 0.9078
# Epoch 120/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2328 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.2982 - val_sparse_categorical_accuracy: 0.9089
# Epoch 121/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.2954 - val_sparse_categorical_accuracy: 0.9083
# Epoch 122/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2998 - val_sparse_categorical_accuracy: 0.9078
# Epoch 123/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2972 - val_sparse_categorical_accuracy: 0.9089
# Epoch 124/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2370 - sparse_categorical_accuracy: 0.9306 - val_loss: 0.3008 - val_sparse_categorical_accuracy: 0.9099
# Epoch 125/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2249 - sparse_categorical_accuracy: 0.9348 - val_loss: 0.2925 - val_sparse_categorical_accuracy: 0.9073
# Epoch 126/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2224 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.2945 - val_sparse_categorical_accuracy: 0.9083
# Epoch 127/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2306 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.2942 - val_sparse_categorical_accuracy: 0.9120
# Epoch 128/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2321 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2959 - val_sparse_categorical_accuracy: 0.9120
# Epoch 129/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2250 - sparse_categorical_accuracy: 0.9339 - val_loss: 0.2924 - val_sparse_categorical_accuracy: 0.9115
# Epoch 130/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2224 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.2922 - val_sparse_categorical_accuracy: 0.9135
# Epoch 131/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2192 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.2909 - val_sparse_categorical_accuracy: 0.9120
# Epoch 132/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2284 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2901 - val_sparse_categorical_accuracy: 0.9125
# Epoch 133/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2184 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2940 - val_sparse_categorical_accuracy: 0.9130
# Epoch 134/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2213 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.2895 - val_sparse_categorical_accuracy: 0.9115
# Epoch 135/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2221 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.2906 - val_sparse_categorical_accuracy: 0.9094
# Epoch 136/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2250 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.2898 - val_sparse_categorical_accuracy: 0.9135
# Epoch 137/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2201 - sparse_categorical_accuracy: 0.9335 - val_loss: 0.2864 - val_sparse_categorical_accuracy: 0.9135
# Epoch 138/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2104 - sparse_categorical_accuracy: 0.9382 - val_loss: 0.2870 - val_sparse_categorical_accuracy: 0.9109
# Epoch 139/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2121 - sparse_categorical_accuracy: 0.9413 - val_loss: 0.2891 - val_sparse_categorical_accuracy: 0.9130
# Epoch 140/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2156 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.2877 - val_sparse_categorical_accuracy: 0.9141
# Epoch 141/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2245 - sparse_categorical_accuracy: 0.9320 - val_loss: 0.2850 - val_sparse_categorical_accuracy: 0.9115
# Epoch 142/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2162 - sparse_categorical_accuracy: 0.9400 - val_loss: 0.2866 - val_sparse_categorical_accuracy: 0.9156
# Epoch 143/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.2864 - val_sparse_categorical_accuracy: 0.9130
# Epoch 144/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2103 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.2870 - val_sparse_categorical_accuracy: 0.9120
# Epoch 145/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2094 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.2867 - val_sparse_categorical_accuracy: 0.9141
# Epoch 146/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2242 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.2862 - val_sparse_categorical_accuracy: 0.9120
# Epoch 147/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2135 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.2853 - val_sparse_categorical_accuracy: 0.9099
# Epoch 148/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9366 - val_loss: 0.2842 - val_sparse_categorical_accuracy: 0.9120
# Epoch 149/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2137 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.2842 - val_sparse_categorical_accuracy: 0.9141
# Epoch 150/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2143 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.2867 - val_sparse_categorical_accuracy: 0.9120
# Epoch 151/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2128 - sparse_categorical_accuracy: 0.9349 - val_loss: 0.2845 - val_sparse_categorical_accuracy: 0.9146
# Epoch 152/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2147 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.2860 - val_sparse_categorical_accuracy: 0.9130
# Epoch 153/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2112 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.2835 - val_sparse_categorical_accuracy: 0.9172
# Epoch 154/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2082 - sparse_categorical_accuracy: 0.9424 - val_loss: 0.2801 - val_sparse_categorical_accuracy: 0.9198
# Epoch 155/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2051 - sparse_categorical_accuracy: 0.9406 - val_loss: 0.2823 - val_sparse_categorical_accuracy: 0.9151
# Epoch 156/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2070 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.2839 - val_sparse_categorical_accuracy: 0.9182
# Epoch 157/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.2790 - val_sparse_categorical_accuracy: 0.9161
# Epoch 158/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2048 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.2785 - val_sparse_categorical_accuracy: 0.9156
# Epoch 159/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2066 - sparse_categorical_accuracy: 0.9418 - val_loss: 0.2791 - val_sparse_categorical_accuracy: 0.9187
# Epoch 160/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2016 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.2817 - val_sparse_categorical_accuracy: 0.9182
# Epoch 161/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2020 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.2802 - val_sparse_categorical_accuracy: 0.9172
# Epoch 162/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2043 - sparse_categorical_accuracy: 0.9405 - val_loss: 0.2771 - val_sparse_categorical_accuracy: 0.9146
# Epoch 163/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9400 - val_loss: 0.2749 - val_sparse_categorical_accuracy: 0.9193
# Epoch 164/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2058 - sparse_categorical_accuracy: 0.9406 - val_loss: 0.2796 - val_sparse_categorical_accuracy: 0.9167
# Epoch 165/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2049 - sparse_categorical_accuracy: 0.9404 - val_loss: 0.2777 - val_sparse_categorical_accuracy: 0.9161
# Epoch 166/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2011 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.2762 - val_sparse_categorical_accuracy: 0.9151
# Epoch 167/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2042 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.2826 - val_sparse_categorical_accuracy: 0.9125
# Epoch 168/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1916 - sparse_categorical_accuracy: 0.9484 - val_loss: 0.2761 - val_sparse_categorical_accuracy: 0.9151
# Epoch 169/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1987 - sparse_categorical_accuracy: 0.9405 - val_loss: 0.2823 - val_sparse_categorical_accuracy: 0.9167
# Epoch 170/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2048 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.2794 - val_sparse_categorical_accuracy: 0.9141
# Epoch 171/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1983 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.2754 - val_sparse_categorical_accuracy: 0.9130
# Epoch 172/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2006 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.2759 - val_sparse_categorical_accuracy: 0.9182
# Epoch 173/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2050 - sparse_categorical_accuracy: 0.9410 - val_loss: 0.2744 - val_sparse_categorical_accuracy: 0.9141
# Epoch 174/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2006 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.2753 - val_sparse_categorical_accuracy: 0.9141
# Epoch 175/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1967 - sparse_categorical_accuracy: 0.9457 - val_loss: 0.2737 - val_sparse_categorical_accuracy: 0.9135
# Epoch 176/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2011 - sparse_categorical_accuracy: 0.9392 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.9172
# Epoch 177/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9418 - val_loss: 0.2728 - val_sparse_categorical_accuracy: 0.9193
# Epoch 178/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2023 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.9177
# Epoch 179/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1998 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.2743 - val_sparse_categorical_accuracy: 0.9214
# Epoch 180/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1977 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.2746 - val_sparse_categorical_accuracy: 0.9208
# Epoch 181/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.2736 - val_sparse_categorical_accuracy: 0.9193
# Epoch 182/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1962 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.2743 - val_sparse_categorical_accuracy: 0.9187
# Epoch 183/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1989 - sparse_categorical_accuracy: 0.9428 - val_loss: 0.2696 - val_sparse_categorical_accuracy: 0.9187
# Epoch 184/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1948 - sparse_categorical_accuracy: 0.9439 - val_loss: 0.2734 - val_sparse_categorical_accuracy: 0.9177
# Epoch 185/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1910 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.2684 - val_sparse_categorical_accuracy: 0.9182
# Epoch 186/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1903 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.2686 - val_sparse_categorical_accuracy: 0.9182
# Epoch 187/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1943 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.2695 - val_sparse_categorical_accuracy: 0.9198
# Epoch 188/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1925 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.2685 - val_sparse_categorical_accuracy: 0.9224
# Epoch 189/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1881 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.2646 - val_sparse_categorical_accuracy: 0.9245
# Epoch 190/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1951 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.2695 - val_sparse_categorical_accuracy: 0.9240
# Epoch 191/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1832 - sparse_categorical_accuracy: 0.9470 - val_loss: 0.2670 - val_sparse_categorical_accuracy: 0.9203
# Epoch 192/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1893 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.9245
# Epoch 193/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.2008 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 0.9271
# Epoch 194/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.2642 - val_sparse_categorical_accuracy: 0.9214
# Epoch 195/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1883 - sparse_categorical_accuracy: 0.9482 - val_loss: 0.2666 - val_sparse_categorical_accuracy: 0.9224
# Epoch 196/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1841 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.2624 - val_sparse_categorical_accuracy: 0.9245
# Epoch 197/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1818 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.2620 - val_sparse_categorical_accuracy: 0.9229
# Epoch 198/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1908 - sparse_categorical_accuracy: 0.9445 - val_loss: 0.2701 - val_sparse_categorical_accuracy: 0.9260
# Epoch 199/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1840 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.2675 - val_sparse_categorical_accuracy: 0.9214
# Epoch 200/200
# 60/60 [==============================] - 27s 447ms/step - loss: 0.1825 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.2641 - val_sparse_categorical_accuracy: 0.9214

# %%
model.evaluate(x_test, y_test, verbose=1)

# %%
from keras.models import load_model

model.save(path + 'transformer_encoder.h5')

# %%
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)

print('')
print('loss_and_metrics : ' + str(loss_and_metrics))
# Out:
# 75/75 [==============================] - 3s 41ms/step - loss: 0.3786 - sparse_categorical_accuracy: 0.8938
#
# loss_and_metrics : [0.3785507082939148, 0.893750011920929]

# %%
print('정답률 = ', loss_and_metrics[1],'loss=', loss_and_metrics[0])
# Out:
# 정답률 =  0.893750011920929 loss= 0.3785507082939148

# %%
hist = model

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('Accuracy')
plt.legend(['train','test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train','test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-c2a779f86b71> in <module>()
# ----> 1 plt.plot(hist.history['acc'])
#       2 plt.plot(hist.history['val_acc'])
#       3 plt.title('Accuracy')
#       4 plt.legend(['train','test'], loc='upper left')
#       5 plt.show()
#
# TypeError: 'History' object is not subscriptable

# %%
# 6. 모델 사용하기
xhat_idx = np.random.choice(x_test.shape[0], 5)
xhat = x_test[xhat_idx]

yhat = model.predict_classes(xhat)

for i in range(5):
    print('True : ' + str(argmax(y_test[xhat_idx[i]])) + ', Predict : ' + str(yhat[i]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-cfec98d83639> in <module>()
#       2 xhat_idx = np.random.choice(x_test.shape[0], 5)
#       3 xhat = x_test[xhat_idx]
# ----> 4 yhat = model.predict_classes(xhat)
#       5
#       6 for i in range(5):
#
# AttributeError: 'Functional' object has no attribute 'predict_classes'
